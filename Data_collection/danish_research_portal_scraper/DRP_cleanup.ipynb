# %%
import pandas as pd

df = pd.read_csv('danish_research_all.csv', sep=(';'))

df.head(50)
# Out:
#                source_file              author  \
# 0            Aaen__Jon.lst           Aaen, Jon
# 1            Aaen__Jon.lst           Aaen, Jon
# 2            Aaen__Jon.lst           Aaen, Jon
# 3            Aaen__Jon.lst           Aaen, Jon
# 4            Aaen__Jon.lst           Aaen, Jon
# 5            Aaen__Jon.lst           Aaen, Jon
# 6            Aaen__Jon.lst           Aaen, Jon
# 7            Aaen__Jon.lst           Aaen, Jon
# 8            Aaen__Jon.lst           Aaen, Jon
# 9            Aaen__Jon.lst           Aaen, Jon
# 10           Aaen__Jon.lst           Aaen, Jon
# 11           Aaen__Jon.lst           Aaen, Jon
# 12           Aaen__Jon.lst           Aaen, Jon
# 13           Aaen__Jon.lst           Aaen, Jon
# 14           Aaen__Jon.lst           Aaen, Jon
# 15      Abdullah__Amna.lst      Abdullah, Amna
# 16      Abdullah__Amna.lst      Abdullah, Amna
# 17     Acciai__Claudia.lst     Acciai, Claudia
# 18     Acciai__Claudia.lst     Acciai, Claudia
# ...
