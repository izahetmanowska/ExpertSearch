# %%
import pandas as pd

# Load files
keywords = pd.read_csv("../CsvForDB/Keywords.csv")
drp = pd.read_csv("DRP.csv")

# Combine title + abstract into one searchable column
drp["search_text"] = (
    drp["title"].fillna("") + " " + drp["abstract"].fillna("")
).str.lower()

# Match keywords
rows = []

for _, paper in drp.iterrows():
    for _, kw in keywords.iterrows():
        term = str(kw["normalized_term"]).strip().lower()
        if term and term in paper["search_text"]:
            rows.append({
                "DRPId": paper["researchPortalId"],
                "keywordID": kw["keywordId"]
            })

# Save result
result = pd.DataFrame(rows).drop_duplicates()
result.to_csv("../CsvForDB/DRPPaperKeywords.csv", index=False)

result.head()
# Out:
#                DRPId  keywordID
# 0  S01-000.00-438089          8
# 1  S01-000.00-438089         57
# 2  S01-000.00-438089         86
# 3  S01-000.00-438089         87
# 4  S01-000.00-438089         88

# %%
import pandas as pd

# Load file
df = pd.read_csv("DRP.csv")

# Select columns and rename researchPortalId → DRPId
df_new = df[[
    "researchPortalId",
    "year",
    "title",
    "type",
    "abstract",
    "file",
    "totalNumberOfContributors"
]].rename(columns={
    "researchPortalId": "DRPId"
})

# Save to new CSV
df_new.to_csv("../CsvForDB/DRPPaper.csv", index=False)

# Preview result
df_new.head()
# Out:
#                DRPId  year                                              title  \
# 0  S01-000.00-438089  2022  "Affective Publics" : Performing Trust on Dani...
# 1  S01-000.00-829674  2025  "Danske reaktioner på grønlandsk selvstyre, se...
# 2  S01-000.00-482896  2016  "Det lille vand" : russernes forhold til vodka...
# 3  S01-000.00-098927  2021  "Does Vinegar Kill Coronavirus?" - Using Searc...
# 4  S01-000.00-444355  2013  "European Spallation Source - Technical Design...
#
#                type                                           abstract  \
# 0   Journal Article  In Denmark, as with elsewhere in the world, Tw...
# 1              Book                                                NaN
# 2      Book Chapter                                                NaN
# 3  Conference Paper  Health experts and government authorities' act...
# 4    Report Chapter                                                NaN
#
#                                                 file  \
# 0                                     10.1086/719645
# 1  https://pure.diis.dk/ws/files/27733344/Dilemma...
# 2                        http://e-pages.dk/ku/1205/2
# 3  https://vbn.aau.dk/ws/files/393455744/iConf202...
# 4                                                NaN
#
#    totalNumberOfContributors
# 0                          5
# 1                          2
# 2                          3
# 3                          2
# 4                         20

# %%
import csv
import pandas as pd

people = set()

with open("DRP.csv", "r", encoding="utf-8", newline="") as f:
    reader = csv.DictReader(f)
    
    for row in reader:
        # Get both columns safely
        author_1 = row.get("author", "")
        author_2 = row.get("authors", "")
        
        # Combine them
        combined = []
        if author_1:
            combined.extend(author_1.split(";"))
        if author_2:
            combined.extend(author_2.split(";"))
        
        # Clean and store unique names
        for person in combined:
            person = person.strip()
            if person:
                people.add(person)

# Split "Last, First" into separate columns
rows = []
for i, person in enumerate(sorted(people), start=1):
    parts = [p.strip() for p in person.split(",", 1)]
    
    if len(parts) == 2:
        last_name, first_name = parts[0], parts[1]
    else:
        last_name, first_name = person, ""
    
    rows.append([i, first_name, last_name])

# Create dataframe
df_people = pd.DataFrame(rows, columns=["DRPPersonId", "firstName", "lastName"])

# Save CSV
df_people.to_csv("../CsvForDB/DRPPerson.csv", index=False)

# Show first rows
df_people.head(20)
# Out:
#     DRPPersonId                                          firstName  \
# 0             1                                   PRIS study group
# 1             2                                            Leen M.
# 2             3                                          Peter A C
# 3             4                                             Leen M
# 4             5                                            Leen M.
# 5             6                                            Nils A.
# 6             7                                          Peter A C
# 7             8                                             Andrea
# 8             9  Det Fragmentariske Institut for Komparative Ti...
# 9            10  International Multiple Sclerosis Genetics Cons...
# 10           11                      NCD Risk Factor Collaboration
# 11           12                                       Jette Blands
# 12           13                                       Verena Baake
# 13           14                                           Gianluca
# 14           15                                                 X.
# 15           16                                                 I.
# 16           17                                                 J.
# 17           18                                                 J.
# 18           19                                                 J.
# 19           20                                           Henrik G
#
#            lastName
# 0                 &
# 1           'T Hart
# 2           'T Hoen
# 3           't Hart
# 4           't Hart
# 5           't Hart
# 6           't Hoen
# 7       't Mannetje
# 8            (FIKT)
# 9           (IMSGC)
# 10       (NCD-RisC)
# 11        (formand)
# 12  (formerly Rödig
# 13
# 14           -G. Lu
# 15          -K. Yoo
# 16       -P. Coffin
# 17        -P. Revol
# 18    -Y. Grossiord
# 19          . Bruun

# %%
import csv
import pandas as pd

# Load DRPPerson.csv
df_people = pd.read_csv("../CsvForDB/DRPPerson.csv")

# Make a lookup: "Last, First" -> person info
person_lookup = {}
for _, row in df_people.iterrows():
    full_name = f"{str(row['lastName']).strip()}, {str(row['firstName']).strip()}".strip()
    person_lookup[full_name] = {
        "DRPPersonId": row["DRPPersonId"],
        "personName": row["firstName"],
        "personLastName": row["lastName"]
    }

# Build DRPPaperContributors rows
rows = []

with open("DRP.csv", "r", encoding="utf-8", newline="") as f:
    reader = csv.DictReader(f)

    for row in reader:
        drp_id = row.get("researchPortalId", "")
        author = row.get("author", "")
        authors = row.get("authors", "")

        contributors = []

        if author:
            contributors.extend(author.split(";"))
        if authors:
            contributors.extend(authors.split(";"))

        # Clean names and remove duplicates within same paper
        contributors = list(dict.fromkeys([c.strip() for c in contributors if c.strip()]))

        for contributor in contributors:
            if contributor in person_lookup:
                rows.append({
                    "DRPId": drp_id,
                    "DRPPersonId": person_lookup[contributor]["DRPPersonId"],
                    "personName": person_lookup[contributor]["personName"],
                    "personLastName": person_lookup[contributor]["personLastName"]
                })
            else:
                # Optional: keep unmatched names visible
                parts = [p.strip() for p in contributor.split(",", 1)]
                last_name = parts[0] if len(parts) > 0 else ""
                first_name = parts[1] if len(parts) > 1 else ""

                rows.append({
                    "DRPId": drp_id,
                    "DRPPersonId": "",
                    "personName": first_name,
                    "personLastName": last_name
                })

# Create dataframe
df_contributors = pd.DataFrame(rows)

# Save CSV
df_contributors.to_csv("../CsvForDB/DRPPaperContributors.csv", index=False)

# Preview
df_contributors.head(20)
# Out:
#                 DRPId DRPPersonId          personName personLastName
# 0   S01-000.00-438089      110493              Tobias       Pedersen
# 1   S01-000.00-438089       16424       Samantha Dawn        Breslin
# 2   S01-000.00-438089       13581              Anders           Blok
# 3   S01-000.00-438089       36650          Thyge Ryom       Enggaard
# 4   S01-000.00-438089       50725              Tobias        Gårdhus
# 5   S01-000.00-438089      110333         Morten Axel       Pedersen
# 6   S01-000.00-829674       78146              Henrik         Larsen
# 7   S01-000.00-829674       63005                Uffe       Jakobsen
# 8   S01-000.00-482896      102177              Jesper        Nielsen
# 9   S01-000.00-482896       42031                 Kim   Frederichsen
# 10  S01-000.00-098927       93264             Florian          Meier
# 11  S01-000.00-098927      153597             Andreas       Windfeld
# 12  S01-000.00-098927       93265  Florian Maximilian          Meier
# 13  S01-000.00-444355       52897            Nicholas         Hansen
# 14  S01-000.00-444355        5602                Lise         Arleth
# 15  S01-000.00-444355       11747                Mads      Bertelsen
# 16  S01-000.00-444355       12713        Jonas Okkels           Birk
# 17  S01-000.00-444355       14812          Heloisa N.       Bordallo
# 18  S01-000.00-444355       20612              Henrik        Carlsen
# 19  S01-000.00-444355       53132      Ursula Bengård         Hansen
